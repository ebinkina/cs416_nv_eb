# %%
import pandas as pd

# %%
df = pd.read_csv("fbi_final_dashboard.csv")
df
# Out:
#                     Area  Year  Population2  Violent crime3  \
# 0    United States Total  2015    320896618         1234183
# 1    United States Total  2016    323127513         1283058
# 2              Northeast  2015     56184737          180474
# 3         North Carolina  2016     56209510          178244
# 4            New England  2015     14710229           42121
# ..                   ...   ...          ...             ...
# 135               Oregon  2016      4093465           10830
# 136           Washington  2015      7160290           20505
# 137           Washington  2016      7288000           22023
# 138          Puerto Rico  2015      3473181            7629
# 139          Puerto Rico  2016      3411307            7643
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)4  \
# 0                                   15883                      126134
# 1                                   17250                      130603
# ...

# %%
df_filtered = df[~((df['Year'] == 2015) & (df['Area'] != 'North Dakota'))]
df_filtered
# Out:
#                     Area  Year  Population2  Violent crime3  \
# 1    United States Total  2016    323127513         1283058
# 3         North Carolina  2016     56209510          178244
# 5            New England  2016     14735525           41598
# 7            Connecticut  2016      3576452            8123
# 9                  Maine  2016      1331479            1648
# ..                   ...   ...          ...             ...
# 131           California  2016     39250017          174796
# 133               Hawaii  2016      1428557            4417
# 135               Oregon  2016      4093465           10830
# 137           Washington  2016      7288000           22023
# 139          Puerto Rico  2016      3411307            7643
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)4  \
# 1                                   17250                      130603
# 3                                    1955                       16651
# ...

# %%
df_filtered["Area"].unique()
# Out:
# array(['United States Total', 'North Carolina', 'New England',
#        'Connecticut', 'Maine', 'Massachusetts', 'New Hampshire',
#        'Rhode Island', 'Vermont', 'Middle Atlantic', 'New Jersey',
#        'New York', 'Pennsylvania', 'Midwest', 'East North Central',
#        'Illinois', 'Indiana', 'Michigan', 'Ohio', 'Wisconsin',
#        'West North Central', 'Iowa', 'Kansas', 'Minnesota', 'Missouri',
#        'Nebraska', 'North Dakota', 'South Dakota', 'South', 'Alaska',
#        'Arizona', 'California', 'Colorado', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Maryland',
#        'South Carolina', 'Virginia', 'West Virginia',
#        'East South Central', 'Alabama', 'Kentucky', 'Mississippi',
#        'Tennessee', 'West South Central', 'Arkansas', 'Louisiana',
#        'Oklahoma', 'Texas', 'West', 'Mountain', 'Idaho', 'Montana',
#        'Nevada', 'New Mexico', 'Utah', 'Wyoming', 'Pacific', 'Hawaii',
# ...

# %%
valid_states = [
    "North Carolina", "Connecticut", "Maine", "Massachusetts", "New Hampshire",
    "Rhode Island", "Vermont", "New Jersey", "New York", "Pennsylvania",
    "Illinois", "Indiana", "Michigan", "Ohio", "Wisconsin", "Iowa", "Kansas",
    "Minnesota", "Missouri", "Nebraska", "North Dakota", "South Dakota", "Alaska",
    "Arizona", "California", "Colorado", "Delaware", "District of Columbia",
    "Florida", "Georgia", "Maryland", "South Carolina", "Virginia", "West Virginia",
    "Alabama", "Kentucky", "Mississippi", "Tennessee", "Arkansas", "Louisiana",
    "Oklahoma", "Texas", "Idaho", "Montana", "Nevada", "New Mexico", "Utah",
    "Wyoming", "Puerto Rico","Hawaii","Washington","Oregon","North Dakota"
]

# %%
df_filtered_2 = df_filtered[df_filtered["Area"].isin(valid_states)]
df_filtered_2=df_filtered_2.reset_index()
df_filtered_2=df_filtered_2.drop(["index"],axis=1)
df_filtered_2
# Out:
#                     Area  Year  Population2  Violent crime3  \
# 0         North Carolina  2016     56209510          178244
# 1            Connecticut  2016      3576452            8123
# 2                  Maine  2016      1331479            1648
# 3          Massachusetts  2016      6811779           25677
# 4          New Hampshire  2016      1334795            2637
# 5           Rhode Island  2016      1056426            2524
# 6                Vermont  2016       624594             989
# 7             New Jersey  2016      8944469           21914
# 8               New York  2016     19745289           74285
# 9           Pennsylvania  2016     12784227           42447
# 10              Illinois  2016     12859995           55869
# 11               Indiana  2016      6633053           24827
# 12              Michigan  2016      9928301           40298
# 13                  Ohio  2016     11614373           36580
# 14             Wisconsin  2016      5779076           24347
# ...

# %%
all_states = df_filtered_2["Area"].unique()
all_states
# Out:
# array(['North Carolina', 'Connecticut', 'Maine', 'Massachusetts',
#        'New Hampshire', 'Rhode Island', 'Vermont', 'New Jersey',
#        'New York', 'Pennsylvania', 'Illinois', 'Indiana', 'Michigan',
#        'Ohio', 'Wisconsin', 'Iowa', 'Kansas', 'Minnesota', 'Missouri',
#        'Nebraska', 'North Dakota', 'South Dakota', 'Alaska', 'Arizona',
#        'California', 'Colorado', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Maryland', 'South Carolina', 'Virginia',
#        'West Virginia', 'Alabama', 'Kentucky', 'Mississippi', 'Tennessee',
#        'Arkansas', 'Louisiana', 'Oklahoma', 'Texas', 'Idaho', 'Montana',
#        'Nevada', 'New Mexico', 'Utah', 'Wyoming', 'Hawaii', 'Oregon',
#        'Washington', 'Puerto Rico'], dtype=object)

# %%
len(all_states)
# Out:
# 52

# %%
state_region_map = {
    'Alabama': 'Southeast',
    'Alaska': 'West',
    'Arizona': 'West',
    'Arkansas': 'South',
    'California': 'West',
    'Colorado': 'West',
    'Connecticut': 'Northeast',
    'Delaware': 'Northeast',
    'Florida': 'Southeast',
    'Georgia': 'Southeast',
    'Hawaii': 'West',
    'Idaho': 'West',
    'Illinois': 'Midwest',
    'Indiana': 'Midwest',
    'Iowa': 'Midwest',
    'Kansas': 'Midwest',
    'Kentucky': 'Southeast',
    'Louisiana': 'South',
    'Maine': 'Northeast',
    'Maryland': 'Northeast',
    'Massachusetts': 'Northeast',
    'Michigan': 'Midwest',
    'Minnesota': 'Midwest',
    'Mississippi': 'South',
    'Missouri': 'Midwest',
    'Montana': 'West',
    'Nebraska': 'Midwest',
    'Nevada': 'West',
    'New Hampshire': 'Northeast',
    'New Jersey': 'Northeast',
    'New Mexico': 'West',
    'New York': 'Northeast',
    'North Carolina': 'Southeast',
    'North Dakota': 'Midwest',
    'Ohio': 'Midwest',
    'Oklahoma': 'South',
    'Oregon': 'West',
    'Pennsylvania': 'Northeast',
    'Rhode Island': 'Northeast',
    'South Carolina': 'Southeast',
    'South Dakota': 'Midwest',
    'Tennessee': 'Southeast',
    'Texas': 'South',
    'Utah': 'West',
    'Vermont': 'Northeast',
    'Virginia': 'Southeast',
    'Washington': 'West',
    'West Virginia': 'Southeast',
    'Wisconsin': 'Midwest',
    'Wyoming': 'West',
    "District of Columnia":'Northeast',
    "Puerto Rico":'Island'
}

# %%
df_filtered_2["Region"] = df_filtered_2["Area"].map(state_region_map)
df_filtered_2
# Out:
#                     Area  Year  Population2  Violent crime3  \
# 0         North Carolina  2016     56209510          178244
# 1            Connecticut  2016      3576452            8123
# 2                  Maine  2016      1331479            1648
# 3          Massachusetts  2016      6811779           25677
# 4          New Hampshire  2016      1334795            2637
# 5           Rhode Island  2016      1056426            2524
# 6                Vermont  2016       624594             989
# 7             New Jersey  2016      8944469           21914
# 8               New York  2016     19745289           74285
# 9           Pennsylvania  2016     12784227           42447
# 10              Illinois  2016     12859995           55869
# 11               Indiana  2016      6633053           24827
# 12              Michigan  2016      9928301           40298
# 13                  Ohio  2016     11614373           36580
# 14             Wisconsin  2016      5779076           24347
# ...

# %%
df_filtered_2.to_csv('fbi.csv', index=False)
